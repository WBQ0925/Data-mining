# %%
from IPython.display import Image
Image(filename="D:\研究生文件\course documents\数据挖掘\HW5\第一题.jpg",width=400,height=400)

# %%
Image(filename="D:\研究生文件\course documents\数据挖掘\HW5\第二题.jpg",width=400,height=400)
